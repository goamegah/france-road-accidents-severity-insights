# %% [markdown]
# # OpenWeather

# %%
import requests
import time

# %%
import requests

class BaseAPIFetcher:
    """
    Classe de base pour interroger des APIs.
    Peut être étendue pour intégrer différentes APIs avec des paramètres spécifiques.
    """
    def __init__(self, base_url, api_key=None, api_value=None):
        self.base_url = base_url
        self.api_key = api_key
        self.api_value = api_value

    def fetch(self, params=None, headers=None):
        headers = headers or {}
        params = params or {}

        if self.api_key and self.api_value:
            params[self.api_key] = self.api_value

        response = requests.get(self.base_url, params=params, headers=headers)
        
        try:
            data = response.json()
        except ValueError as e:
            print("Erreur lors du parsing JSON :", e)
            return None

        if response.status_code == 200:
            return data
        else:
            print(f"Erreur API ({response.status_code}) :", data)
            return None


class OpenWeatherMapHistoricalFetcher(BaseAPIFetcher):
    """
    Classe dédiée à l'API OpenWeatherMap (historique).
    """
    def __init__(self, api_key):
        base_url = "https://history.openweathermap.org/data/2.5/history/city"
        # "appid" est la clé attendue par OpenWeatherMap
        super().__init__(base_url, api_key="appid", api_value=api_key)

    def get_historical_data(self, lat, lon, start=None, end=None, cnt=None):
        params = {
            "lat": lat,
            "lon": lon,
            "type": "hour",  # requis par l'API
        }

        if start:
            params["start"] = start
        if end:
            params["end"] = end
        if cnt:
            params["cnt"] = cnt

        return self.fetch(params=params)

# %%
class OpenWeatherMapDayForecastFetcher(BaseAPIFetcher):
    """
    Client pour l'API de prévisions météo d'OpenWeatherMap.
    """
    def __init__(self, api_key):
        base_url = "http://api.openweathermap.org/data/2.5/forecast"
        super().__init__(base_url, api_key="appid", api_value=api_key)

    def get_day_forecast_data_by_coordinates(self, lat, lon, units="metric"):
        """
        Récupère les prévisions météo pour des coordonnées géographiques.
        :param lat: Latitude
        :param lon: Longitude
        :param units: Unités de mesure (par défaut "metric")
        :return: Données météo
        """
        params = {
            "lat": lat,
            "lon": lon,
            "units": units
        }
        return self.fetch(params=params)

    def get_day_forecast_data_by_zip(self, zip_code, units="metric"):
        """
        Récupère les prévisions météo pour un code postal.
        :param zip_code: Code postal
        :param units: Unités de mesure (par défaut "metric")
        :return: Données météo
        """
        params = {
            "zip": zip_code,
            "units": units
        }
        return self.fetch(params=params)

    def get_day_forecast_data_by_city_id(self, city_id, units="metric"):
        """
        Récupère les prévisions météo pour une ville donnée par son ID.
        :param city_id: ID de la ville
        :param units: Unités de mesure (par défaut "metric")
        :return: Données météo
        """
        params = {
            "id": city_id,
            "units": units
        }
        return self.fetch(params=params)

    def get_day_forecast_data_by_city_name(self, city_name, units="metric"):
        """
        Récupère les prévisions météo pour une ville donnée par son nom.
        :param city_name: Nom de la ville
        :param units: Unités de mesure (par défaut "metric")
        :return: Données météo
        """
        params = {
            "q": city_name,
            "units": units
        }
        return self.fetch(params=params)

# %%
def to_unix_timestamp(date_str, format="%Y-%m-%d"):
    """
    Convertit une date string (ex: '2024-03-01') en timestamp Unix.
    """
    return int(time.mktime(time.strptime(date_str, format)))

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("OPEN_WEATHER_API_KEY")
api_key
# Out:
# '24c85c33a7f10723da7c9427b24e84a6'

# %% [markdown]
# ## Historical API Call

# %%
lat, lon = 34.0901, -118.4065
start = to_unix_timestamp("2025-04-19")
end = to_unix_timestamp("2025-04-20")

print("start", start)
print("end", end)
# Out:
# start 1745013600
# end 1745100000

# %%
fetcher = OpenWeatherMapHistoricalFetcher(api_key)
data = fetcher.get_historical_data(lat, lon, start=start, end=end)

# %%
print(data)
# Out:
# {'message': 'Count: 25', 'cod': '200', 'city_id': 1, 'calctime': 0.007142652, 'cnt': 25, 'list': [{'dt': 1745013600, 'main': {'temp': 289.57, 'feels_like': 288.89, 'pressure': 1014, 'humidity': 62, 'temp_min': 288.49, 'temp_max': 291.19}, 'wind': {'speed': 6.17, 'deg': 250}, 'clouds': {'all': 40}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]}, {'dt': 1745017200, 'main': {'temp': 289.41, 'feels_like': 288.71, 'pressure': 1014, 'humidity': 62, 'temp_min': 288.22, 'temp_max': 291.25}, 'wind': {'speed': 5.14, 'deg': 270}, 'clouds': {'all': 20}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]}, {'dt': 1745020800, 'main': {'temp': 289.38, 'feels_like': 288.68, 'pressure': 1014, 'humidity': 62, 'temp_min': 288.23, 'temp_max': 290.62}, 'wind': {'speed': 4.63, 'deg': 250}, 'clouds': {'all': 40}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}]}, {'dt': 1745024400, 'main': {'temp': 288.29, 'feels_like': 287.56, 'pressure': 1014, 'humidity': 65, 'temp_min': 287.32, 'temp_max': 289.65}, 'wind': {'speed': 4.12, 'deg': 170}, 'clouds': {'all': 100}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1745028000, 'main': {'temp': 287.34, 'feels_like': 286.67, 'pressure': 1015, 'humidity': 71, 'temp_min': 286.55, 'temp_max': 288.8}, 'wind': {'speed': 3.6, 'deg': 270}, 'clouds': {'all': 100}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}]}, {'dt': 1745031600, 'main': {'temp': 286.74, 'feels_like': 286.06, 'pressure': 1015, 'humidity': 73, 'temp_min': 285.87, 'temp_max': 288.47}, 'wind': {'speed': 3.09, 'deg': 170}, 'clouds': {'all': 100}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1745035200, 'main': {'temp': 286.4, 'feels_like': 285.79, 'pressure': 1016, 'humidity': 77, 'temp_min': 285.77, 'temp_max': 288.23}, 'wind': {'speed': 2.57, 'deg': 230}, 'clouds': {'all': 40}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}]}, {'dt': 1745038800, 'main': {'temp': 286.04, 'feels_like': 285.42, 'pressure': 1017, 'humidity': 78, 'temp_min': 285.28, 'temp_max': 287.68}, 'wind': {'speed': 2.57, 'deg': 270}, 'clouds': {'all': 100}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1745042400, 'main': {'temp': 285.72, 'feels_like': 285.07, 'pressure': 1017, 'humidity': 78, 'temp_min': 285.06, 'temp_max': 287.29}, 'wind': {'speed': 2.06, 'deg': 100}, 'clouds': {'all': 75}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}]}, {'dt': 1745046000, 'main': {'temp': 285.53, 'feels_like': 284.89, 'pressure': 1018, 'humidity': 79, 'temp_min': 284.51, 'temp_max': 287.06}, 'wind': {'speed': 1.54, 'deg': 190}, 'clouds': {'all': 0}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}]}, {'dt': 1745049600, 'main': {'temp': 284.82, 'feels_like': 284.13, 'pressure': 1018, 'humidity': 80, 'temp_min': 283.78, 'temp_max': 286.57}, 'wind': {'speed': 2.06, 'deg': 140}, 'clouds': {'all': 20}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}]}, {'dt': 1745053200, 'main': {'temp': 285.01, 'feels_like': 284.31, 'pressure': 1018, 'humidity': 79, 'temp_min': 283.8, 'temp_max': 286.67}, 'wind': {'speed': 0.89, 'deg': 343, 'gust': 1.79}, 'clouds': {'all': 100}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1745056800, 'main': {'temp': 285.07, 'feels_like': 284.43, 'pressure': 1018, 'humidity': 81, 'temp_min': 283.75, 'temp_max': 286.48}, 'wind': {'speed': 0.89, 'deg': 326, 'gust': 1.34}, 'clouds': {'all': 100}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}]}, {'dt': 1745060400, 'main': {'temp': 284.68, 'feels_lik ...

# %% [markdown]
# ## Day API Call

# %%
city_name = "London"
fetcher = OpenWeatherMapDayForecastFetcher(api_key)

# %%
data = fetcher.get_day_forecast_data_by_coordinates(lat, lon)
print(data)
# Out:
# {'cod': '200', 'message': 0, 'cnt': 40, 'list': [{'dt': 1745182800, 'main': {'temp': 18.64, 'feels_like': 18.07, 'temp_min': 18.64, 'temp_max': 21.57, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 997, 'humidity': 58, 'temp_kf': -2.93}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'clouds': {'all': 0}, 'wind': {'speed': 3.78, 'deg': 210, 'gust': 2.92}, 'visibility': 9106, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-04-20 21:00:00'}, {'dt': 1745193600, 'main': {'temp': 18.59, 'feels_like': 17.91, 'temp_min': 18.49, 'temp_max': 18.59, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 995, 'humidity': 54, 'temp_kf': 0.1}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'clouds': {'all': 23}, 'wind': {'speed': 3.56, 'deg': 206, 'gust': 3.5}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-04-21 00:00:00'}, {'dt': 1745204400, 'main': {'temp': 17.37, 'feels_like': 16.52, 'temp_min': 16.73, 'temp_max': 17.37, 'pressure': 1016, 'sea_level': 1016, 'grnd_level': 995, 'humidity': 52, 'temp_kf': 0.64}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 66}, 'wind': {'speed': 2.05, 'deg': 211, 'gust': 1.89}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-04-21 03:00:00'}, {'dt': 1745215200, 'main': {'temp': 12.22, 'feels_like': 10.99, 'temp_min': 12.22, 'temp_max': 12.22, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 995, 'humidity': 57, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'clouds': {'all': 73}, 'wind': {'speed': 1.21, 'deg': 145, 'gust': 1.39}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-04-21 06:00:00'}, {'dt': 1745226000, 'main': {'temp': 11.24, 'feels_like': 10.06, 'temp_min': 11.24, 'temp_max': 11.24, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 994, 'humidity': 63, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 94}, 'wind': {'speed': 1.07, 'deg': 168, 'gust': 1.19}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-04-21 09:00:00'}, {'dt': 1745236800, 'main': {'temp': 11.38, 'feels_like': 10.3, 'temp_min': 11.38, 'temp_max': 11.38, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 994, 'humidity': 66, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'clouds': {'all': 97}, 'wind': {'speed': 1.15, 'deg': 161, 'gust': 1.4}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'n'}, 'dt_txt': '2025-04-21 12:00:00'}, {'dt': 1745247600, 'main': {'temp': 14.92, 'feels_like': 14.14, 'temp_min': 14.92, 'temp_max': 14.92, 'pressure': 1014, 'sea_level': 1014, 'grnd_level': 994, 'humidity': 64, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 100}, 'wind': {'speed': 0.88, 'deg': 124, 'gust': 1.02}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-04-21 15:00:00'}, {'dt': 1745258400, 'main': {'temp': 18.71, 'feels_like': 17.89, 'temp_min': 18.71, 'temp_max': 18.71, 'pressure': 1015, 'sea_level': 1015, 'grnd_level': 994, 'humidity': 48, 'temp_kf': 0}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'clouds': {'all': 93}, 'wind': {'speed': 2.76, 'deg': 182, 'gust': 1.88}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-04-21 18:00:00'}, {'dt': 1745269200, 'main': {'temp': 20.39, 'feels_like': 19.63, 'temp_min': 20.39, 'temp_max': 20.39, 'pressure': 1013, 'sea_level': 1013, 'grnd_level': 993, 'humidity': 44, 'temp_kf': 0}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 84}, 'wind': {'speed': 3.53, 'deg': 197, 'gust': 2.49}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2025-04-2 ...

# %%
API_KEY = "24c85c33a7f10723da7c9427b24e84a6"
CITY = "Paris"
#start_date = datetime.now() - timedelta(5)
#URL = f"https://api.openweathermap.org/data/3.0/onecall/timemachine?lat=48.8566&lon=2.3522&dt={int(start_date.timestamp())}&appid={API_KEY}&units=metric"
URL = f"http://api.openweathermap.org/data/2.5/forecast?q={CITY}&appid={API_KEY}&units=metric"

# %%
response = requests.get(URL)
weather_data = response.json()

# %%
weather_data
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1745182800,
#    'main': {'temp': 10.79,
#     'feels_like': 10.3,
#     'temp_min': 10.79,
#     'temp_max': 10.79,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 75},
#    'wind': {'speed': 3.61, 'deg': 110, 'gust': 7.43},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.24},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-20 21:00:00'},
#   {'dt': 1745193600,
#    'main': {'temp': 10.84,
#     'feels_like': 10.33,
#     'temp_min': 10.84,
#     'temp_max': 10.93,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 90,
#     'temp_kf': -0.09},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 83},
#    'wind': {'speed': 3.46, 'deg': 114, 'gust': 7.18},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.26},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-21 00:00:00'},
#   {'dt': 1745204400,
#    'main': {'temp': 10.65,
#     'feels_like': 10.04,
#     'temp_min': 10.58,
#     'temp_max': 10.65,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 996,
#     'humidity': 87,
#     'temp_kf': 0.07},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 2.07, 'deg': 126, 'gust': 4.96},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.17},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-21 03:00:00'},
#   {'dt': 1745215200,
#    'main': {'temp': 11.17,
#     'feels_like': 10.59,
#     'temp_min': 11.17,
#     'temp_max': 11.17,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 997,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.09, 'deg': 330, 'gust': 1.66},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.1},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-21 06:00:00'},
#   {'dt': 1745226000,
#    'main': {'temp': 11.58,
#     'feels_like': 10.88,
#     'temp_min': 11.58,
#     'temp_max': 11.58,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1000,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.85, 'deg': 299, 'gust': 2.78},
#    'visibility': 10000,
#    'pop': 0.41,
#    'rain': {'3h': 0.32},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-21 09:00:00'},
#   {'dt': 1745236800,
#    'main': {'temp': 11.68,
#     'feels_like': 10.6,
#     'temp_min': 11.68,
#     'temp_max': 11.68,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1001,
#     'humidity': 65,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.67, 'deg': 276, 'gust': 3.88},
#    'visibility': 10000,
#    'pop': 0.63,
#    'rain': {'3h': 0.28},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-21 12:00:00'},
#   {'dt': 1745247600,
#    'main': {'temp': 15.33,
#     'feels_like': 14.38,
#     'temp_min': 15.33,
#     'temp_max': 15.33,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1002,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.45, 'deg': 300, 'gust': 3.84},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-21 15:00:00'},
#   {'dt': 1745258400,
#    'main': {'temp': 13.49,
#     'feels_like': 12.91,
#     'temp_min': 13.49,
#     'temp_max': 13.49,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1003,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.95, 'deg': 277, 'gust': 5.2},
#    'visibility': 10000,
#    'pop': 0.45,
#    'rain': {'3h': 0.46},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-21 18:00:00'},
#   {'dt': 1745269200,
#    'main': {'temp': 11.6,
#     'feels_like': 11.09,
#     'temp_min': 11.6,
#     'temp_max': 11.6,
#     'pressure': 1015,
#     'sea_level': 1015,
#     'grnd_level': 1006,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.81, 'deg': 271, 'gust': 5.28},
#    'visibility': 10000,
#    'pop': 0.29,
#    'rain': {'3h': 0.15},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-21 21:00:00'},
#   {'dt': 1745280000,
#    'main': {'temp': 10.91,
#     'feels_like': 10.35,
#     'temp_min': 10.91,
#     'temp_max': 10.91,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1006,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.28, 'deg': 287, 'gust': 3.04},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-22 00:00:00'},
#   {'dt': 1745290800,
#    'main': {'temp': 9.63,
#     'feels_like': 9.63,
#     'temp_min': 9.63,
#     'temp_max': 9.63,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1007,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 35},
#    'wind': {'speed': 1.14, 'deg': 289, 'gust': 1.31},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-22 03:00:00'},
#   {'dt': 1745301600,
#    'main': {'temp': 9.7,
#     'feels_like': 9.7,
#     'temp_min': 9.7,
#     'temp_max': 9.7,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1008,
#     'humidity': 86,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 55},
#    'wind': {'speed': 0.9, 'deg': 278, 'gust': 1.39},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-22 06:00:00'},
#   {'dt': 1745312400,
#    'main': {'temp': 14.16,
#     'feels_like': 13.09,
#     'temp_min': 14.16,
#     'temp_max': 14.16,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1009,
#     'humidity': 56,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 1.35, 'deg': 285, 'gust': 1.57},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-22 09:00:00'},
#   {'dt': 1745323200,
#    'main': {'temp': 17.35,
#     'feels_like': 16.16,
#     'temp_min': 17.35,
#     'temp_max': 17.35,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1009,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 2.56, 'deg': 296, 'gust': 3.16},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-22 12:00:00'},
#   {'dt': 1745334000,
#    'main': {'temp': 17.87,
#     'feels_like': 16.63,
#     'temp_min': 17.87,
#     'temp_max': 17.87,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1008,
#     'humidity': 35,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 3.55, 'deg': 291, 'gust': 3.41},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-22 15:00:00'},
#   {'dt': 1745344800,
#    'main': {'temp': 16.38,
#     'feels_like': 15.07,
#     'temp_min': 16.38,
#     'temp_max': 16.38,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1009,
#     'humidity': 38,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 2.58, 'deg': 300, 'gust': 3.18},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-22 18:00:00'},
#   {'dt': 1745355600,
#    'main': {'temp': 13.75,
#     'feels_like': 12.69,
#     'temp_min': 13.75,
#     'temp_max': 13.75,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1010,
#     'humidity': 58,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.29, 'deg': 351, 'gust': 3.75},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-22 21:00:00'},
#   {'dt': 1745366400,
#    'main': {'temp': 12.79,
#     'feels_like': 11.72,
#     'temp_min': 12.79,
#     'temp_max': 12.79,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1009,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 94},
#    'wind': {'speed': 1.11, 'deg': 57, 'gust': 1.48},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-23 00:00:00'},
#   {'dt': 1745377200,
#    'main': {'temp': 11.75,
#     'feels_like': 10.65,
#     'temp_min': 11.75,
#     'temp_max': 11.75,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1008,
#     'humidity': 64,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 95},
#    'wind': {'speed': 2.06, 'deg': 227, 'gust': 4.2},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-23 03:00:00'},
#   {'dt': 1745388000,
#    'main': {'temp': 10.3,
#     'feels_like': 9.14,
#     'temp_min': 10.3,
#     'temp_max': 10.3,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1007,
#     'humidity': 67,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 96},
#    'wind': {'speed': 3.02, 'deg': 211, 'gust': 6.15},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-23 06:00:00'},
#   {'dt': 1745398800,
#    'main': {'temp': 10.41,
#     'feels_like': 9.33,
#     'temp_min': 10.41,
#     'temp_max': 10.41,
#     'pressure': 1018,
#     'sea_level': 1018,
#     'grnd_level': 1008,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.89, 'deg': 217, 'gust': 6.41},
#    'visibility': 10000,
#    'pop': 0.58,
#    'rain': {'3h': 0.36},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-23 09:00:00'},
#   {'dt': 1745409600,
#    'main': {'temp': 9.39,
#     'feels_like': 7.4,
#     'temp_min': 9.39,
#     'temp_max': 9.39,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1007,
#     'humidity': 83,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.7, 'deg': 161, 'gust': 7.1},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 2.03},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-23 12:00:00'},
#   {'dt': 1745420400,
#    'main': {'temp': 9.24,
#     'feels_like': 7.52,
#     'temp_min': 9.24,
#     'temp_max': 9.24,
#     'pressure': 1016,
#     'sea_level': 1016,
#     'grnd_level': 1006,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.13, 'deg': 150, 'gust': 6.93},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 0.77},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-23 15:00:00'},
#   {'dt': 1745431200,
#    'main': {'temp': 9.34,
#     'feels_like': 8.13,
#     'temp_min': 9.34,
#     'temp_max': 9.34,
#     'pressure': 1017,
#     'sea_level': 1017,
#     'grnd_level': 1007,
#     'humidity': 87,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.37, 'deg': 160, 'gust': 4.07},
#    'visibility': 10000,
#    'pop': 0.68,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-23 18:00:00'},
#   {'dt': 1745442000,
#    'main': {'temp': 9.48,
#     'feels_like': 9.48,
#     'temp_min': 9.48,
#     'temp_max': 9.48,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1009,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.12, 'deg': 149, 'gust': 1.86},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-23 21:00:00'},
#   {'dt': 1745452800,
#    'main': {'temp': 8.45,
#     'feels_like': 7.95,
#     'temp_min': 8.45,
#     'temp_max': 8.45,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1009,
#     'humidity': 95,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 88},
#    'wind': {'speed': 1.44, 'deg': 153, 'gust': 2.12},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-24 00:00:00'},
#   {'dt': 1745463600,
#    'main': {'temp': 9.05,
#     'feels_like': 9.05,
#     'temp_min': 9.05,
#     'temp_max': 9.05,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1009,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.04, 'deg': 181, 'gust': 2.61},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-24 03:00:00'},
#   {'dt': 1745474400,
#    'main': {'temp': 9.39,
#     'feels_like': 9.39,
#     'temp_min': 9.39,
#     'temp_max': 9.39,
#     'pressure': 1019,
#     'sea_level': 1019,
#     'grnd_level': 1009,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.02, 'deg': 178, 'gust': 2.05},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-24 06:00:00'},
#   {'dt': 1745485200,
#    'main': {'temp': 12.28,
#     'feels_like': 11.55,
#     'temp_min': 12.28,
#     'temp_max': 12.28,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1010,
#     'humidity': 76,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 0.56, 'deg': 250, 'gust': 1.28},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-24 09:00:00'},
#   {'dt': 1745496000,
#    'main': {'temp': 14.88,
#     'feels_like': 14.02,
#     'temp_min': 14.88,
#     'temp_max': 14.88,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1010,
#     'humidity': 61,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 1.71, 'deg': 12, 'gust': 1.71},
#    'visibility': 10000,
#    'pop': 0.2,
#    'rain': {'3h': 0.28},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-24 12:00:00'},
#   {'dt': 1745506800,
#    'main': {'temp': 13.8,
#     'feels_like': 13.01,
#     'temp_min': 13.8,
#     'temp_max': 13.8,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1010,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 2.41, 'deg': 342, 'gust': 3.17},
#    'visibility': 10000,
#    'pop': 0.76,
#    'rain': {'3h': 0.36},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-24 15:00:00'},
#   {'dt': 1745517600,
#    'main': {'temp': 13.74,
#     'feels_like': 12.81,
#     'temp_min': 13.74,
#     'temp_max': 13.74,
#     'pressure': 1020,
#     'sea_level': 1020,
#     'grnd_level': 1011,
#     'humidity': 63,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 2.02, 'deg': 354, 'gust': 3.82},
#    'visibility': 10000,
#    'pop': 0.33,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-24 18:00:00'},
#   {'dt': 1745528400,
#    'main': {'temp': 11.7,
#     'feels_like': 10.86,
#     'temp_min': 11.7,
#     'temp_max': 11.7,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1012,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 62},
#    'wind': {'speed': 1.54, 'deg': 354, 'gust': 2.77},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-24 21:00:00'},
#   {'dt': 1745539200,
#    'main': {'temp': 10.57,
#     'feels_like': 9.88,
#     'temp_min': 10.57,
#     'temp_max': 10.57,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1013,
#     'humidity': 84,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 58},
#    'wind': {'speed': 1.52, 'deg': 13, 'gust': 2.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-25 00:00:00'},
#   {'dt': 1745550000,
#    'main': {'temp': 9.41,
#     'feels_like': 8.9,
#     'temp_min': 9.41,
#     'temp_max': 9.41,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1013,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01n'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 1.57, 'deg': 26, 'gust': 3.6},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2025-04-25 03:00:00'},
#   {'dt': 1745560800,
#    'main': {'temp': 9.38,
#     'feels_like': 8.81,
#     'temp_min': 9.38,
#     'temp_max': 9.38,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1013,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 9},
#    'wind': {'speed': 1.63, 'deg': 32, 'gust': 3.35},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-25 06:00:00'},
#   {'dt': 1745571600,
#    'main': {'temp': 14.34,
#     'feels_like': 13.08,
#     'temp_min': 14.34,
#     'temp_max': 14.34,
#     'pressure': 1023,
#     'sea_level': 1023,
#     'grnd_level': 1014,
#     'humidity': 48,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 8},
#    'wind': {'speed': 1.93, 'deg': 34, 'gust': 2.37},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-25 09:00:00'},
#   {'dt': 1745582400,
#    'main': {'temp': 18.76,
#     'feels_like': 17.58,
#     'temp_min': 18.76,
#     'temp_max': 18.76,
#     'pressure': 1022,
#     'sea_level': 1022,
#     'grnd_level': 1013,
#     'humidity': 34,
#     'temp_kf': 0},
#    'weather': [{'id': 800,
#      'main': 'Clear',
#      'description': 'clear sky',
#      'icon': '01d'}],
#    'clouds': {'all': 10},
#    'wind': {'speed': 1.42, 'deg': 44, 'gust': 1.4},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-25 12:00:00'},
#   {'dt': 1745593200,
#    'main': {'temp': 19.78,
#     'feels_like': 18.62,
#     'temp_min': 19.78,
#     'temp_max': 19.78,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1011,
#     'humidity': 31,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 99},
#    'wind': {'speed': 1.76, 'deg': 45, 'gust': 1.59},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-25 15:00:00'},
#   {'dt': 1745604000,
#    'main': {'temp': 18.06,
#     'feels_like': 16.94,
#     'temp_min': 18.06,
#     'temp_max': 18.06,
#     'pressure': 1021,
#     'sea_level': 1021,
#     'grnd_level': 1011,
#     'humidity': 39,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 2.07, 'deg': 61, 'gust': 3.46},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2025-04-25 18:00:00'}],
#  'city': {'id': 2988507,
#   'name': 'Paris',
#   'coord': {'lat': 48.8534, 'lon': 2.3488},
#   'country': 'FR',
#   'population': 2138551,
#   'timezone': 7200,
#   'sunrise': 1745124585,
#   'sunset': 1745174931}}
